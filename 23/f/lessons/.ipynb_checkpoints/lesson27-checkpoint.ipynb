# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Loading in the Data and Functions

# %%
united = Table.read_table('data/united.csv')
united_bins = np.arange(-20, 300, 10)
united.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Date</th> <th>Flight Number</th> <th>Destination</th> <th>Delay</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>6/1/15</td> <td>73           </td> <td>HNL        </td> <td>257  </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>217          </td> <td>EWR        </td> <td>28   </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>237          </td> <td>STL        </td> <td>-3   </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>250          </td> <td>SAN        </td> <td>0    </td>
#         </tr>
#         <tr>
#             <td>6/1/15</td> <td>267          </td> <td>PHL        </td> <td>64   </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (13820 rows omitted)</p>

# %%
def one_sample_mean(sample_size):
    """ Takes a sample from the population of flights and computes its mean"""
    sampled_flights = united.sample(sample_size)
    return np.mean(sampled_flights.column('Delay'))

# %%
def ten_thousand_sample_means(sample_size):
    means = make_array()
    for i in np.arange(10000):
        mean = one_sample_mean(sample_size)
        means = np.append(means, mean)
    return means

# %% [markdown]
# ## Distribution of the Sample Average

# %%
united.hist('Delay', bins=united_bins)

# %%
# How many possible sample means are there?
13825 ** 400
# Out:
# ...

# %%
united.hist('Delay', bins=united_bins)

# %%
means_tbl = Table().with_columns(
    '100', ten_thousand_sample_means(100),
    '256', ten_thousand_sample_means(256),
    '400', ten_thousand_sample_means(400),
    '625', ten_thousand_sample_means(625),
    '900', ten_thousand_sample_means(900)
)

# %%
means_tbl
# Out:
# 100   | 256     | 400     | 625     | 900
# 16.15 | 14.8164 | 19.3725 | 18.7344 | 16.6978
# 12.01 | 17.1133 | 15.23   | 19.2624 | 14.7344
# 16.59 | 18.7695 | 16.5225 | 16.3792 | 17.9367
# 16.17 | 15.9258 | 17.0325 | 19.8816 | 21.1056
# 16.2  | 18.3281 | 14.95   | 18.3552 | 14.2656
# 11.74 | 17.0859 | 16.7325 | 18.1232 | 14.79
# 13.25 | 14.207  | 16.0875 | 19.552  | 17.4144
# 13.82 | 14.4141 | 15.955  | 15.4928 | 17.0322
# 17.08 | 13.8516 | 17.79   | 18.6976 | 16.9578
# 16.76 | 13.457  | 16.8475 | 18.536  | 20.82
# ... (9990 rows omitted)

# %%
means_tbl.hist(bins = np.arange(5, 31, 0.5))
plt.title('Distribution of Sample Average');

# %% [markdown]
# ## Variability of the Sample Average

# %%
delay_mean = np.mean(united.column('Delay'))
delay_sd = np.std(united.column('Delay'))

# %%
delay_mean
# Out:
# 16.658155515370705

# %%
delay_sd
# Out:
# 39.480199851609314

# %%
"""Empirical distribution of random sample means"""

def summarize_sample_means():
        
    print("Population mean:", delay_mean)
    print("Population SD:", delay_sd)
    
    for i in np.arange(len(means_tbl)):
        print('')
        print("Sample size: ", means_tbl.labels[i])
        print("Average of sample means: ", np.mean(means_tbl.column(i)))
        print("SD of sample means:", np.std(means_tbl.column(i)))
        print("Ratio of Pop SD to SD of sample means", delay_sd / np.std(means_tbl.column(i)))

# %%
summarize_sample_means()
# Out:
# Population mean: 16.6581555154
# Population SD: 39.4801998516
#
# Sample size:  100
# Average of sample means:  16.623635
# SD of sample means: 3.88782139209
# Ratio of Pop SD to SD of sample means 10.1548388853
#
# Sample size:  256
# Average of sample means:  16.6469023437
# SD of sample means: 2.5018409907
# Ratio of Pop SD to SD of sample means 15.7804592691
#
# Sample size:  400
# Average of sample means:  16.65428325
# SD of sample means: 1.95685977765
# Ratio of Pop SD to SD of sample means 20.1752830236
#
# Sample size:  625
# Average of sample means:  16.65370672
# SD of sample means: 1.58102717586
# Ratio of Pop SD to SD of sample means 24.9712341788
#
# Sample size:  900
# Average of sample means:  16.6799954444
# SD of sample means: 1.31853332429
# Ratio of Pop SD to SD of sample means 29.9425119747
