# %% [markdown]
# # Homework 04: Machine Learning Algorithms
#
# Welcome to Homework 04! To receive credit for a homework assignment, answer all questions correctly and submit before the deadline.
#
# **Due Date:** Wednesday, May 3, 2023 at 11:59 p.m.
#
# **Collaboration Policy:** You are not allowed to discuss this assignment with other students. If you have questions please refer them to your partner and/or your instructor.
#
# ## Introduction
#
# For this project you'll have a partner. Those have been automatically assigned and you can find your partner's information on the assignment page in Canvas. You should not discuss the assignment with anyone outside your group. If you are stuck please contact your instructor. If you run into issues with your partner, let me know immediately. I can't help if it is the day before the due date and you tell me you haven't heard from him/her/them. You'll be stuck doing it yourself then.
#
# For this assignment you will create a python notebook. This file should then be uploaded to Gradescope through Canvas in the assignment link (all group members should submit this notebook). When submitting, please leave a note about how working with your group members went and if you think he/she/they gave equal effort or not. Please use the following rubric as a guide.
#
# |               |  | **Points** |  |
# |:--------------|:-:|:-:         |:-:|
# |**Description**|3  |2|1|
# |Equal Work|Did an equal share of work|Did almost as much work as others|Did little to no work|
# |Cooperation|Work agreeably with others|Could be persuaded to cooperate|Did not cooperate|
# |Participation|Participated in discussions <br />and made some suggestions|Listened to others but <br /> offered few suggestions|Did not participate or listen to sugges- <br /> tions and offered little to no suggestions|
# |Support|Assisted other group members|Seemed preoccupied with their own work|Took little to no interest in others' work|
# |Communication|Usually shared ideas|Rarely expressed ideas|Never expressed any ideas
#
# This assignment is meant to assess your ability to program in python. The result should be a report with a narrative throughout, section headings, graphs outputted in appropriate places, etc. To be clear make sure to include markdown text describing what you are doing, even when not explicitly asked for. The audience you are writing for is someone that understands programming and very basic statistics, but would need you to provide details and explanation of what you are doing to understand it.
#
# This homework assignment will have a part that pushes you beyond what was done in class. Learning to search for the right questions and browsing are data science and computing skills that you should hone.
#
# ## Overall Instructions
#
# You will read in a data set, do some basic exploratory data analysis (EDA, numeric summaries, graphs), and then implement an algorithm on the data from scratch.
#
# ## Data Sheet
# You'll be using a data set containing information about motorcycle sales available at the assignment link in Canvas. The original data can be found on [Kaggle by clicking here](https://www.kaggle.com/datasets/nehalbirla/motorcycle-dataset?select=BIKE+DETAILS.csv). The variables in the data set are:
#
# |**Name**|**Description**|
# |:-------|:--------------|
# |`name`|Name of motorcycle|
# |`selling_price`| |
# |`year`|Year of motorcycle|
# |`seller_type`| |
# |`owner`|Number of owners|
# |`ex_showroom_price`| |
# |`km_driven`| |

# %% [markdown]
# # Report Components
#
# ## Introduction
# First, you should have a small section that introduces the purpose of the report and the data set you'll be working with. You should read in the data and display a small snippet of it. You should also describe the packages (modules) you'll use for your analysis.

# %% [markdown]
# ## Exploratory Data Analysis
# Next, you should have a section where you explore the data. The variable we are most interested is the `selling_price` (often called our response variable). You'll want to focus your EDA on this variable but feel free to display relationships between other variables as well. Ideally, I'd leave this part off and let you explore the data (as that is a skill to develop). That being said, along with the fact that this may be a new experience for you, I'll provide some basic guidance here:
#
# - You should have numeric summaries of the `selling_price` variable (at different levels/combinations of other variables).
# - You should have plots of the `selling_price` variable (again showing relationships with other variables).
# - You should create at least one two-way contingency table with corresponding side-by-side/stacked bar plot visual.

# %% [markdown]
# ## Prediction
# We want to be able to predict a value of `selling_price` for a new motorcycle. How do we figure out what a good prediction would be? We need to quantify the **quality** of the prediction. This is usually done through a **loss function**.

# %% [markdown]
# ## Loss Function
# Suppose there is some prediction (call it $c$). How do we measure the quality of $c$? We want  something "close" to all the known values of `selling_price` from our data set. A common metric to use is squared error loss. The squared error loss for a data point (call it $y_1$) and a prediction ($c$) is
#
# $$L_{\left(y_1,c\right)}=\left(y_1-c\right)^2$$
#
# For a given set of data $y_1,y_2, \ldots, y_n$ (the `selling_price` values), we could consider the mean squared error $$\text{Root Mean Sqaure Error }= \text{ RMSE }(c)=\sqrt{\frac{1}{n} \sum\limits_{i=1}^n L\left(y_i,c\right)}=\sqrt{\frac{1}{n} \sum\limits_{i=1}^n \left(y_i-c\right)^2}$$ We can use numerical methods to quantify the quality based off of this equation. So we now want to choose the value of $c$ that minimizes this equation (smaller loss means better prediction $-$ closer to all the points).

# %% [markdown]
# ## Grid Search
#
# ## Using a Grid Search Algorithm
#
# You'll be implementing a grid search to find the optimal value of c based off of our data set.
#
# ### Grid Search Pseudo-code Using $y$
# Below is pseudo-code to help you write your code.
#
# 1. Create a *grid* of values for $c$. Use your EDA to determine reasonable values to consider for $c$.
#
# 1. Create a squared error loss function that takes in y and c that outputs $(y-c)^2$.
#
# 1. Create a root mean squared error (objective) function that takes in $y$ and $c$ that outputs
#
# $$\text{RMSE}(c)=\sqrt{\frac{1}{n}\sum\limits_{i=1}^n(y-c)^2}$$
#
# **Note:** You can put step 2 and 3 into one function if you want.
#
# 1. Loop over the grid of $c$ values, finding the RMSE for each value of $c$.
#
# 1. Determine which value of $c$ gives the optimal (smallest) RMSE.
#
# 1. Report that as the prediction!
#
#     - Run your algorithm on the `selling_price` variable and determine the optimal prediction.
#
#     - Just to make sure your algorithm generalizes, run it using the `km_driven` variable as the response (this should not involve any new functions, just new function calls.

# %% [markdown]
# ## Grid Search Using $y$ and Another Numeric Variable $x$
#
# Next, you'll implement the grid search to find the optimal pair of values for `b0` and `b1` using `km_driven` as your `x` variable and `selling_price` as your `y` variable. The pseudo code is very similar to that above, but your grid now has two-dimensions. You'll need to populate a grid of `b0` and `b1` values that you want to consider (again use your EDA to your advantage). Be sure to explain how you decided upon your grid
#
# Use your "best" combination of `b0` and `b1` to predict the selling_price for km_driven of 10000, 25000, and 35000.

# %% [markdown]
# ## Gradient Descent
# In mathematics gradient descent is a first-order iterative optimization algorithm for finding a local minimum of a differentiable function. The idea is to take repeated steps in the opposite direction of the gradient (or approximate gradient) of the function at the current point, because this is the direction of steepest descent (Wikipedia).
#
# You'll implement this algorithm for two equations representing $c$:
#
# - One where you don't consider any data other than the $y$'s. That is, $c$ is going to just be a constant that minimizes the function.
#
#   **Note:** The calculus based answer for this comes out to be the sample mean, $\bar y$.
# - One where you consider a linear equation of one other numeric variable. That is, you have a different prediction for each observation $i$ given by $c_i = b_0 + b_1x_i$. Here $x_i$ is one of the other numeric variables from our data set (`km_driven`).
#
#    **Note:** The calculus based answer for this comes out to be the usual **simple linear regression estimates**, which you can find using `scipy.stats` (we'll learn more about this later in the course).
#
# ## Using a Gradient Descent Algorithm}
# We can implement our own Gradient Descent Algorithm in python. We'll go through the ideas in class.
#
# ### Gradient Descent Pseudo-code Using $y$
# Below is pseudo-code to help you write your code.
#
# 1. Create a squared error loss function that takes in $y$ and $c$ and outputs $(y-c)^2$.
#
# 1. Create a root mean squared error (objective) function that takes in $y$ and $c$ and outputs
#
# $$\text{RMSE}(c)=\sqrt{\frac{1}{n}\sum\limits_{i=1}^n(y-c)^2}$$
#
# 1. Create a difference quotient function to approximate the slope of the tangent line that takes in the guess $c$, a small change to $c$ (call it $\Delta$), and $y$ that outputs
#
# $$\text{difference_quotient }=\frac{\text{RMSE}(c+\Delta)-\text{ RMSE}(c)}{\Delta}$$
#
# 1. Choose a starting value for `cur_c`.
#
# 1. Evaluate the difference quotient at `cur_c`.
#
# 1. Update the value by moving (a small step) in the negative direction of the difference quotient `new_c = cur_c - difference_quotient` $\cdot$ `step_size`.
#
# 1. Check if `abs(new_c - cur_c)` $<$ `num_tol` where `num_tol` is a small value.
#
#     - If so, update the `cur_c` to be the `new_c` value and stop.
#
#     - If not, update the value of `cur_c` to `new_c` and repeat steps 5$-$7.
#
#     - Put in a safety that stops the loop after a maximum number of iterations is reached (even if `abs(new_c - cur_c)` $<$ `num_tol` is not met.
#         \end{itemize}}
#
# 1. Use the last value as the prediction.
#
#    - Run your algorithm on the `selling_price` variable and determine the optimal prediction.
#
#    - Make sure your algorithm generalizes, run it using the `km_driven` variable as the response (this should not involve any new functions, just new function calls.)

# %% [markdown]
# ### Gradient Descent Pseudo-code Using $y$ and Another Numeric Variable $x$
# Next, you'll implement the gradient descent idea to find the optimal value of $b_0$ and $b_1$ using `km_driven` as your $x$ variable and `selling_price` as your $y$ variable. The pseudo code is very similar to that above, but you have two variables to optimize over ($b_0$ and $b_1$) instead of one $(c)$.
#
# 1. Create a squared error loss function that takes in $y$, $x$, $b_0$, and $b_1$ that outputs $(y-b_0-b_1x)^2$.
#
# 2. Create a root mean squared error (objective) function that takes in $y$, $b_0$, and $b_1$ that outputs
#
# $$\text{RMSE}\left(b_0,b_1\right)=\sqrt{\frac{1}{n}\sum\limits_{i=1}^n(y-b_0-b_1x)^2}$$
#
# 3. Create a difference quotient function for $b_0$ to approximate the slope of the tangent line in the direction of $b_0$. It should take in $y$, $x$, $b_0$, a small change to $b_0$ (call it $\Delta_0$), and $b_1$ that outputs
#
# $$\text{difference_quotient_b0 }=\frac{\text{RMSE}(b_0+\Delta_0,b_1)-\text{ RMSE}(b_0,b_1)}{\Delta_0}$$
#
# 4. Create a difference quotient function for $b_1$ to approximate the slope of the tangent line in the direction of $b_1$. It should take in $y$, $x$, $b_0$, $b_1$, and a small change to $b_1$ (call it $\Delta_1$) that outputs
#
# $$\text{difference_quotient\_b1 }=\frac{\text{RMSE}(b_0,b_1+\Delta_1)-\text{ RMSE}(b_0,b_1)}{\Delta_1}$$
#
# 5. Pick starting values for `b0` and `b1` (e.g., `cur_b0` and `cur_b1`).
#
# 6. Evaluate the difference quotient for `b0` at the `cur_b0` and `cur_b1` values.
#
# 7. Update the value of `b0` by moving (a small step) in the negative direction of the difference quotient `new_b0 = cur_b0 - difference_quotient_b0` $\cdot$ `step_size_b0`.
#
# 8. Evaluate the difference quotient for `b1` at the `new_b0` and `cur_b1` values.
#
# 9. Update the value of `b1` by moving (a small step) in the negative direction of the difference quotient `new_b1 = cur_b1 - difference_quotient_b1` $\cdot$ `step_size_b1`.
#
# 10. Check if the distance between the `cur_b0`, `cur_b1` vector to the `new_b0`, `new_b1` vector is less than some small tolerance.
#
#
#    **Hint:** Look up the Euclidean distance between two vectors, there is a function in `numpy` to calculate it$-$or just code it up yourself.
#
#
#    - If so, update the `cur_b0` and `cur_b1` to be the `new_b0` and `new_b1` values and stop.
#
#    - If not, update the `cur_b0` and `cur_b1` to be the `new_b0` and `new_b1` values and repeat steps 6$-$10.
#
#        - Put in a safety that stops the loop after a maximum number of iterations is reached (even if the tolerance is not met).
#
# 11. Use the last values as the estimates for `b0` and `b1`.
#
#
# Use your "best" combination of `b0` and `b1` to predict the `selling_price` for `km_driven` of 10000, 25000 and 35000.
#
# **Note:** You'll need to play around to find reasonable values for your $\Delta$s and step sizes.

# %% [markdown]
# # Files to Submit
#
# - Make sure all cells are run.
#
# - This notebook with your own exploratory work. Be sure to add comments and markdown text to describe your thought processes as you worked. You should have exploratory data analysis, functions for grid search and gradient descent, and visualizations.
#
# - The final notebook (`hw04-final-report.ipynb`) with your report will be a group submission. The instructions for a Gradescope group submission can be found [here.](https://www.youtube.com/watch?v=rue7p_kATLA)
