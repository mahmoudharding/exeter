# %% [markdown]
# # Lesson 12: A Brief Introduction to SQL Clauses
#
# Data scientists work with data stored in tables. This lesson introduces relations, one of the most widely used ways to represent data tables. We'll also introduce SQL, the standard programming language for working with relations.
#
# This lesson introduces operations for taking subsets of relations. When data scientists begin working with a relation, they often want to subset the specific data that they plan to use. For example, a data scientist can slice out the ten relevant features from a relation with hundreds of columns. Or, they can filter a relation to remove rows with incomplete data. For the rest of this chapter, we'll introduce relation operations using a dataset of baby names.
#
# To work with relations, we'll introduce a domain-specific programming language called **SQL (Structured Query Language)**. We commonly pronounce *"SQL"* like *"sequel"* instead of spelling out the acronym. SQL is a specialized language for working with relations—as such, SQL has its own syntax that makes it easier to write programs that operate on relational data.

# %%
import pandas as pd
import numpy as np

# %%
people = pd.read_csv('data/sf-people.csv')
homes = pd.read_csv('data/sf-homes.csv')
pets = pd.read_csv('data/sf-pets.csv')

# %%
people.head()
# Out:
#        name sex  age
# 0    Austin   M   33
# 1     Blair   M   90
# 2  Carolina   F   28
# 3      Dani   F   41
# 4    Donald   M   70

# %%
homes.head()
# Out:
#   owner_name     area   value
# 0     Austin    urban  145000
# 1      Blair  suburbs   95000
# 2   Carolina  suburbs  220000
# 3   Carolina    urban  190000
# 4       Dani  country   67000

# %%
pets.head()
# Out:
#       name  type owner_name
# 0     Maru   cat     Austin
# 1     Icey   dog      Blair
# 2    Maxie   dog      Blair
# 3      Rex   dog   Carolina
# 4  Harambe  bird       Dani

# %% [markdown]
# ## 1. What is SQL Lite?
#
# - [Relational Database](https://www.ibm.com/topics/relational-databases)
# - [SQLite](https://sqlite.org/index.html)
# - [Self-contained](https://www.oreilly.com/library/view/using-sqlite/9781449394592/ch01s01.html)
#
#
# Our database is stored in a file called `simplefolks.db`. This file is a SQLite database, so we'll set up a `sqlalchemy` object that can process this format.

# %%
import sqlalchemy
db = sqlalchemy.create_engine('sqlite:///data/simplefolks.db')

# %% [markdown]
# Let's inspect the tables.

# %%
insp = sqlalchemy.inspect(db)
insp.get_table_names()
# Out:
# ['homes', 'people', 'pets']

# %%
insp.get_columns('people')
# Out:
# [{'name': 'name',
#   'type': TEXT(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'sex',
#   'type': TEXT(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'age',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 0}]

# %% [markdown]
# A relation has rows and columns. Every column has a label.
#
# |**name**|**sex**|**age**|
# |--------|-------|-------|
# |Austin|M|33|
# |Blair|M|90|
# |Carolina|F|28|
#
# Unlike dataframes, however, individual rows in a relation don't have labels. Also, unlike dataframes, rows of a relation aren't ordered.
#
# ### SELECT

# %%
query = ''' 
SELECT name, age, sex
FROM people
WHERE age > 28
LIMIT 5;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#      name  age sex
# 0  Austin   33   M
# 1   Blair   90   M
# 2    Dani   41   F
# 3  Donald   70   M
# 4   Eliza   37   F

# %%
query = ''' 
SELECT name
FROM people;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#         name
# 0     Austin
# 1      Blair
# 2   Carolina
# 3       Dani
# 4     Donald
# 5      Eliza
# 6     Farida
# 7   Georgina
# 8    Hillary
# 9     Leland
# 10      Liam
# 11   Michael
# 12    Phoebe
# 13    Sherry
# 14       Zed

# %% [markdown]
# ### WHERE

# %%
query = ''' 
SELECT name 
FROM people
WHERE sex = 'M';
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#       name
# 0   Austin
# 1    Blair
# 2   Donald
# 3   Leland
# 4     Liam
# 5  Michael
# 6      Zed

# %%
query = ''' 
SELECT name, age
FROM people
WHERE sex = 'M'
LIMIT 5;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#      name  age
# 0  Austin   33
# 1   Blair   90
# 2  Donald   70
# 3  Leland   16
# 4    Liam   22

# %%
query = ''' 
SELECT name, age, sex
FROM people
WHERE age >= 48 AND sex = 'M';
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#       name  age sex
# 0    Blair   90   M
# 1   Donald   70   M
# 2  Michael   48   M

# %% [markdown]
# ### ORDER BY

# %%
query = ''' 
SELECT name, age, sex
FROM people
WHERE age >= 48 AND sex = 'M'
ORDER BY age;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#       name  age sex
# 0  Michael   48   M
# 1   Donald   70   M
# 2    Blair   90   M

# %%
query = ''' 
SELECT name, age, sex
FROM people
WHERE age >= 48 AND sex = 'M'
ORDER BY age DESC;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#       name  age sex
# 0    Blair   90   M
# 1   Donald   70   M
# 2  Michael   48   M

# %% [markdown]
# ### Aggregation

# %%
query = ''' 
SELECT * 
FROM homes;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#    owner_name     area   value
# 0      Austin    urban  145000
# 1       Blair  suburbs   95000
# 2    Carolina  suburbs  220000
# 3    Carolina    urban  190000
# 4        Dani  country   67000
# 5      Donald    urban  450000
# 6      Donald    urban  260000
# 7      Donald    urban  660000
# 8       Eliza    urban  210000
# 9      Farida  suburbs  180000
# 10   Georgina  country   82000
# 11    Hillary  country  380000
# 12    Hillary    urban  400000
# 13       Liam  suburbs  160000
# 14     Leland  country   42000
# 15    Michael  suburbs  160000
# 16    Michael  country   82000
# 17     Phoebe    urban   77000
# 18     Sherry    urban  210000
# 19        Zed  country  177000

# %%
query = ''' 
SELECT * 
FROM homes;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#    owner_name     area   value
# 0      Austin    urban  145000
# 1       Blair  suburbs   95000
# 2    Carolina  suburbs  220000
# 3    Carolina    urban  190000
# 4        Dani  country   67000
# 5      Donald    urban  450000
# 6      Donald    urban  260000
# 7      Donald    urban  660000
# 8       Eliza    urban  210000
# 9      Farida  suburbs  180000
# 10   Georgina  country   82000
# 11    Hillary  country  380000
# 12    Hillary    urban  400000
# 13       Liam  suburbs  160000
# 14     Leland  country   42000
# 15    Michael  suburbs  160000
# 16    Michael  country   82000
# 17     Phoebe    urban   77000
# 18     Sherry    urban  210000
# 19        Zed  country  177000

# %%
query = ''' 
SELECT SUM(value) as total_value
FROM homes;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#    total_value
# 0      4247000

# %% [markdown]
# ### GROUP BY

# %%
query = ''' 
SELECT area as location, SUM(value) as total_value
FROM homes
GROUP BY area;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#   location  total_value
# 0  country       830000
# 1  suburbs       815000
# 2    urban      2602000

# %%
query = ''' 
SELECT owner_name, area, SUM(value)
FROM homes
WHERE owner_name = 'Donald';
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#   owner_name   area  SUM(value)
# 0     Donald  urban     1370000

# %%
query = ''' 
SELECT owner_name, area, SUM(value) as total_value
FROM homes
WHERE owner_name = 'Donald';
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#   owner_name   area  total_value
# 0     Donald  urban      1370000

# %% [markdown]
# ### JOIN

# %%
insp.get_columns('people')
# Out:
# [{'name': 'name',
#   'type': TEXT(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'sex',
#   'type': TEXT(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'age',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0}]

# %%
insp.get_columns('pets')
# Out:
# [{'name': 'name',
#   'type': TEXT(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'type',
#   'type': TEXT(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0},
#  {'name': 'owner_name',
#   'type': TEXT(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': 'auto',
#   'primary_key': 0}]

# %%
query = ''' 
SELECT *
FROM people;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#         name sex  age
# 0     Austin   M   33
# 1      Blair   M   90
# 2   Carolina   F   28
# 3       Dani   F   41
# 4     Donald   M   70
# 5      Eliza   F   37
# 6     Farida   F   23
# 7   Georgina   F   19
# 8    Hillary   F   68
# 9     Leland   M   16
# 10      Liam   M   22
# 11   Michael   M   48
# 12    Phoebe   F   52
# 13    Sherry   F   39
# 14       Zed   M   42

# %%
query = ''' 
SELECT *
FROM pets;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#               name   type owner_name
# 0             Maru    cat     Austin
# 1             Icey    dog      Blair
# 2            Maxie    dog      Blair
# 3              Rex    dog   Carolina
# 4          Harambe   bird       Dani
# 5              Syd    dog       Dani
# 6          Artemis    cat       Dani
# 7      Mr. Muggles    cat     Donald
# 8          Meowser    cat     Donald
# 9           Donald    cat     Donald
# 10           Hodor   bird      Eliza
# 11         Bumpkin  horse   Georgina
# 12     Secretariat  horse    Hillary
# 13           Socks    dog    Hillary
# 14  Sir Barks-Alot    dog       Liam
# 15    Harry Potter  horse     Leland
# 16          Xerses  horse    Michael
# 17            Zeus    cat    Michael
# 18          Rocket    cat     Phoebe
# 19          Kermit    dog     Sherry
# 20          Hector    dog     Sherry
# 21            Essy    dog     Sherry
# 22         Samwise    dog     Sherry
# 23         Jenkins  horse        Zed

# %%
# Inner by default. 
# If there is not a match in 
# both tables nothing is returned.
query = ''' 
SELECT *
FROM people JOIN pets
    ON people.name = pets.owner_name;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#         name sex  age            name   type owner_name
# 0     Austin   M   33            Maru    cat     Austin
# 1      Blair   M   90            Icey    dog      Blair
# 2      Blair   M   90           Maxie    dog      Blair
# 3   Carolina   F   28             Rex    dog   Carolina
# 4       Dani   F   41         Artemis    cat       Dani
# 5       Dani   F   41         Harambe   bird       Dani
# 6       Dani   F   41             Syd    dog       Dani
# 7     Donald   M   70          Donald    cat     Donald
# 8     Donald   M   70         Meowser    cat     Donald
# 9     Donald   M   70     Mr. Muggles    cat     Donald
# 10     Eliza   F   37           Hodor   bird      Eliza
# 11  Georgina   F   19         Bumpkin  horse   Georgina
# 12   Hillary   F   68     Secretariat  horse    Hillary
# 13   Hillary   F   68           Socks    dog    Hillary
# 14    Leland   M   16    Harry Potter  horse     Leland
# 15      Liam   M   22  Sir Barks-Alot    dog       Liam
# 16   Michael   M   48          Xerses  horse    Michael
# 17   Michael   M   48            Zeus    cat    Michael
# 18    Phoebe   F   52          Rocket    cat     Phoebe
# 19    Sherry   F   39            Essy    dog     Sherry
# 20    Sherry   F   39          Hector    dog     Sherry
# 21    Sherry   F   39          Kermit    dog     Sherry
# 22    Sherry   F   39         Samwise    dog     Sherry
# 23       Zed   M   42         Jenkins  horse        Zed

# %%
# Left join returns all observations 
# from the left table. 
# If there is no match the values 
# from the right table will be None.
query = ''' 
SELECT *
FROM people LEFT JOIN pets
    ON people.name = pets.owner_name;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=db.connect())
# Out:
#         name sex  age            name   type owner_name
# 0     Austin   M   33            Maru    cat     Austin
# 1      Blair   M   90            Icey    dog      Blair
# 2      Blair   M   90           Maxie    dog      Blair
# 3   Carolina   F   28             Rex    dog   Carolina
# 4       Dani   F   41         Artemis    cat       Dani
# 5       Dani   F   41         Harambe   bird       Dani
# 6       Dani   F   41             Syd    dog       Dani
# 7     Donald   M   70          Donald    cat     Donald
# 8     Donald   M   70         Meowser    cat     Donald
# 9     Donald   M   70     Mr. Muggles    cat     Donald
# 10     Eliza   F   37           Hodor   bird      Eliza
# 11    Farida   F   23            None   None       None
# 12  Georgina   F   19         Bumpkin  horse   Georgina
# 13   Hillary   F   68     Secretariat  horse    Hillary
# 14   Hillary   F   68           Socks    dog    Hillary
# 15    Leland   M   16    Harry Potter  horse     Leland
# 16      Liam   M   22  Sir Barks-Alot    dog       Liam
# 17   Michael   M   48          Xerses  horse    Michael
# 18   Michael   M   48            Zeus    cat    Michael
# 19    Phoebe   F   52          Rocket    cat     Phoebe
# 20    Sherry   F   39            Essy    dog     Sherry
# 21    Sherry   F   39          Hector    dog     Sherry
# 22    Sherry   F   39          Kermit    dog     Sherry
# 23    Sherry   F   39         Samwise    dog     Sherry
# 24       Zed   M   42         Jenkins  horse        Zed

# %% [markdown]
# ![northwinds.png](images/northwinds.png)

# %%
nw = sqlalchemy.create_engine('sqlite:///data/northwind.db')

# %% [markdown]
# Let's inspect the tables.

# %%
insp = sqlalchemy.inspect(nw)
insp.get_table_names()
# Out:
# ['Categories',
#  'CustomerCustomerDemo',
#  'CustomerDemographics',
#  'Customers',
#  'EmployeeTerritories',
#  'Employees',
#  'Order Details',
#  'Orders',
#  'Products',
#  'Regions',
#  'Shippers',
#  'Suppliers',
#  'Territories']

# %%
insp.get_columns('Orders')
# Out:
# [{'name': 'OrderID',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'primary_key': 1},
#  {'name': 'CustomerID',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'EmployeeID',
#   'type': INTEGER(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'OrderDate',
#   'type': DATETIME(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'RequiredDate',
#   'type': DATETIME(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'ShippedDate',
#   'type': DATETIME(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'ShipVia',
#   'type': INTEGER(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'Freight',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': '0',
#   'primary_key': 0},
#  {'name': 'ShipName',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'ShipAddress',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'ShipCity',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'ShipRegion',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'ShipPostalCode',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0},
#  {'name': 'ShipCountry',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'primary_key': 0}]

# %%
query = ''' 
SELECT *
FROM Employees JOIN Orders
    ON Employees.EmployeeID=Orders.EmployeeID
WHERE Employees.EmployeeID = 1;
'''

pd.read_sql(sql=sqlalchemy.text(query), con=nw.connect())
# Out:
#      EmployeeID LastName FirstName                 Title TitleOfCourtesy  \
# 0             1  Davolio     Nancy  Sales Representative             Ms.
# 1             1  Davolio     Nancy  Sales Representative             Ms.
# 2             1  Davolio     Nancy  Sales Representative             Ms.
# 3             1  Davolio     Nancy  Sales Representative             Ms.
# 4             1  Davolio     Nancy  Sales Representative             Ms.
# ..          ...      ...       ...                   ...             ...
# 118           1  Davolio     Nancy  Sales Representative             Ms.
# 119           1  Davolio     Nancy  Sales Representative             Ms.
# 120           1  Davolio     Nancy  Sales Representative             Ms.
# 121           1  Davolio     Nancy  Sales Representative             Ms.
# 122           1  Davolio     Nancy  Sales Representative             Ms.
#
#       BirthDate    HireDate                    Address     City  \
# 0    1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# 1    1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# 2    1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# 3    1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# 4    1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# ..          ...         ...                        ...      ...
# 118  1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# 119  1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# 120  1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# 121  1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
# 122  1968-12-08  2012-05-01  507 - 20th Ave. E.Apt. 2A  Seattle
#
#             Region  ... RequiredDate ShippedDate ShipVia Freight  \
# 0    North America  ...   2016-08-14  2016-07-23       1  140.51
# 1    North America  ...   2016-08-29  2016-08-02       1  136.54
# 2    North America  ...   2016-09-04  2016-08-09       1   26.93
# 3    North America  ...   2016-09-17  2016-08-26       2   76.83
# 4    North America  ...   2016-09-25  2016-09-02       2    1.35
# ..             ...  ...          ...         ...     ...     ...
# 118  North America  ...   2018-05-29  2018-05-04       1   30.09
# 119  North America  ...   2018-05-18  2018-05-06       2    7.98
# 120  North America  ...   2018-06-01  2018-05-06       2   15.67
# 121  North America  ...   2018-06-02        None       1    0.93
# 122  North America  ...   2018-06-03        None       2    8.53
#
#                          ShipName  \
# 0                    Ernst Handel
# 1                  Wartian Herkku
# 2    Magazzini Alimentari Riuniti
# 3                      QUICK-Stop
# 4          Tradiçao Hipermercados
# ..                            ...
# 118            Save-a-lot Markets
# 119      Drachenblut Delikatessen
# 120           Tortuga Restaurante
# 121             LILA-Supermercado
# 122    Rattlesnake Canyon Grocery
#
#                                         ShipAddress      ShipCity  \
# 0                                      Kirchgasse 6          Graz
# 1                                       Torikatu 38          Oulu
# 2                           Via Ludovico il Moro 22       Bergamo
# 3                                  Taucherstraße 10     Cunewalde
# 4                           Av. Inês de Castro, 414     Sao Paulo
# ..                                              ...           ...
# 118                                 187 Suffolk Ln.         Boise
# 119                                    Walserweg 21        Aachen
# 120                                Avda. Azteca 123   México D.F.
# 121  Carrera 52 con Ave. Bolívar #65-98 Llano Largo  Barquisimeto
# 122                                 2817 Milton Dr.   Albuquerque
#
#           ShipRegion  ShipPostalCode ShipCountry
# 0     Western Europe            8010     Austria
# 1        Scandinavia           90110     Finland
# 2    Southern Europe           24100       Italy
# 3     Western Europe            1307     Germany
# 4      South America       05634-030      Brazil
# ..               ...             ...         ...
# 118    North America           83720         USA
# 119   Western Europe           52066     Germany
# 120  Central America            5033      Mexico
# 121    South America            3508   Venezuela
# 122    North America           87110         USA
#
# [123 rows x 32 columns]
